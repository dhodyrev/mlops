# %%
import os
import pickle
import click
import mlflow
import numpy as np
from hyperopt import STATUS_OK, Trials, fmin, hp, tpe
from hyperopt.pyll import scope
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
# Out:
# /Users/dmytro_khodyriev/mlops/venv/lib/python3.13/site-packages/hyperopt/atpe.py:19: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5000")
mlflow.set_experiment("random-forest-hyperopt")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/2', creation_time=1771425886033, experiment_id='2', last_update_time=1771425886033, lifecycle_stage='active', name='random-forest-hyperopt', tags={}>

# %%
def load_pickle(filename: str):
    with open(filename, "rb") as f_in:
        return pickle.load(f_in)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.log_params(params)
        rf = RandomForestRegressor(**params)
        rf.fit(X_train, y_train)
        y_pred = rf.predict(X_val)
        rmse = np.sqrt(mean_squared_error(y_val, y_pred))
        mlflow.log_metric("rmse", rmse)

    return {"loss": rmse, "status": STATUS_OK}

# %%
data_path = "./output"
num_trials = 20
X_train, y_train = load_pickle(os.path.join(data_path, "train.pkl"))
X_val, y_val = load_pickle(os.path.join(data_path, "val.pkl"))

search_space = {
    "max_depth": scope.int(hp.quniform("max_depth", 1, 20, 1)),
    "n_estimators": scope.int(hp.quniform("n_estimators", 10, 50, 1)),
    "min_samples_split": scope.int(hp.quniform("min_samples_split", 2, 10, 1)),
    "min_samples_leaf": scope.int(hp.quniform("min_samples_leaf", 1, 4, 1)),
    "random_state": 42,
}

rstate = np.random.default_rng(42)
fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=num_trials,
    trials=Trials(),
    rstate=rstate,
)
# Out:
# 🏃 View run flawless-fawn-368 at: http://127.0.0.1:5000/#/experiments/2/runs/bfcf81b7d8a34d9491ea363a4c30dfa5
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run marvelous-stork-231 at: http://127.0.0.1:5000/#/experiments/2/runs/9cc892542392455fa6c4594fd84340f9
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run calm-calf-933 at: http://127.0.0.1:5000/#/experiments/2/runs/8daa1958c5504548857f680445b45c14
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run awesome-horse-343 at: http://127.0.0.1:5000/#/experiments/2/runs/a9d02b1637ad4769bcb6534338595a71
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run brawny-swan-345 at: http://127.0.0.1:5000/#/experiments/2/runs/a3246c51a41c48fdb0af8f642b19ff91
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run fun-asp-405 at: http://127.0.0.1:5000/#/experiments/2/runs/3464f59851ca4e93b5082c61360775b3
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run agreeable-dove-530 at: http://127.0.0.1:5000/#/experiments/2/runs/caf4a17c694247f4a9e25d643c533987
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run defiant-doe-695 at: http://127.0.0.1:5000/#/experiments/2/runs/f7d9fa34ece54bf5be77b7d47f31ddf6
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run burly-finch-926 at: http://127.0.0.1:5000/#/experiments/2/runs/8f1f0c842ce54572a2c6834e77eb2eea
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run rare-lark-268 at: http://127.0.0.1:5000/#/experiments/2/runs/e473326888934e7c886a87bf85979270
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run ambitious-foal-366 at: http://127.0.0.1:5000/#/experiments/2/runs/679d49ed0caf4816aa320f15a626ef0a
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run redolent-bass-571 at: http://127.0.0.1:5000/#/experiments/2/runs/cd928e07ee244837b31f25349836e403
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run fortunate-crow-85 at: http://127.0.0.1:5000/#/experiments/2/runs/e1ce52dd81a5462d99710397fa9b8716
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run sedate-conch-731 at: http://127.0.0.1:5000/#/experiments/2/runs/97f66e5d18d9435abcf69af48a9ed13d
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run colorful-gnat-539 at: http://127.0.0.1:5000/#/experiments/2/runs/78761fbce2b0401cad4a91696a0dfe5a
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run rare-doe-708 at: http://127.0.0.1:5000/#/experiments/2/runs/e077a86e0a4042db8f320b0d8391937c
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run unique-gull-949 at: http://127.0.0.1:5000/#/experiments/2/runs/363cca0f893746d9ac89a96860986aad
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run legendary-rat-460 at: http://127.0.0.1:5000/#/experiments/2/runs/a0e2901ba8b146288386599e1da1ac57
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run placid-swan-788 at: http://127.0.0.1:5000/#/experiments/2/runs/c298eecc1aad4d159d0270c76304c575
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run funny-conch-278 at: http://127.0.0.1:5000/#/experiments/2/runs/1c2236895dfa4fb999c68b8e218275a6
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 100%|██████████| 20/20 [00:28<00:00,  1.42s/trial, best loss: 5.322418787243458]
# {'max_depth': np.float64(20.0),
#  'min_samples_leaf': np.float64(2.0),
#  'min_samples_split': np.float64(3.0),
#  'n_estimators': np.float64(23.0)}
